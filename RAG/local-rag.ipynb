# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.5 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders import CSVLoader

# %%
loader = CSVLoader(file_path=r"D:\The_Egyptian_Food_Bank\Lang-Chain\datasets\titanic_data.csv")
data = loader.load()
print(data[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_loaders/csv_loader.py in lazy_load(self)
#     133         try:
# --> 134             with open(self.file_path, newline="", encoding=self.encoding) as csvfile:
#     135                 yield from self.__read_file(csvfile)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\The_Egyptian_Food_Bank\\Lang-Chain\\datasets\\titanic_data.csv'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-b9e6e722b414> in <cell line: 2>()
#       1 loader = CSVLoader(file_path=r"D:\The_Egyptian_Food_Bank\Lang-Chain\datasets\titanic_data.csv")
# ----> 2 data = loader.load()
#       3 print(data[0])
#
# ...

# %%
# Out:
# File not found. Check the file path.
